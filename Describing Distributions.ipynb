# %% [markdown]
# # Describing Distributions (Core)
#
# Data Enrichment
#
# Author: Nicholas Orgel
#
# Date: 03/07/2023

# %% [markdown]
# Assignment Guidelines:
#
# The Features To Analyze:
# - Vit

# %%
# Import Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
url = 'https://docs.google.com/spreadsheets/d/1APV3pXiAszS_0mSgkiEt9IUNH-QmyX7KwxSAwuADl6Y/gviz/tq?tqx=out:csv&sheet=medical_data'
df_med = pd.read_csv(url)
df_med.head()
# Out:
#   State       Lat       Lng      Area  Children  Age    Income   Marital  \
# 0    AL  34.34960 -86.72508  Suburban       1.0   53  86575.93  Divorced
# 1    FL  30.84513 -85.22907     Urban       3.0   51  46805.99   Married
# 2    SD  43.54321 -96.63772  Suburban       3.0   53  14370.14   Widowed
# 3    MN  43.89744 -93.51479  Suburban       0.0   78  39741.49   Married
# 4    VA  37.59894 -76.88958     Rural       1.0   22   1209.56   Widowed
#
#    Gender  ReAdmis  ...  Hyperlipidemia  BackPain  Anxiety  Allergic_rhinitis  \
# 0    Male        0  ...             0.0       1.0      1.0                1.0
# 1  Female        0  ...             0.0       0.0      0.0                0.0
# 2  Female        0  ...             0.0       0.0      0.0                0.0
# 3    Male        0  ...             0.0       0.0      0.0                0.0
# 4  Female        0  ...             1.0       0.0      0.0                1.0
#
# ...

# %% [markdown]
# ## First Histogram (VitD_levels)

# %%
# Create a histogram of VitD_levels
col = 'VitD_levels'
feature = df_med[col]
mean = feature.mean()
median = feature.median()
std = feature.std()
plus_one_std = mean + std
minus_one_std = mean - std

# ax and fig inputs for each histogram are to be replicated in the other 2 (Doc_visits, TotalCharge)
fig, ax = plt.subplots(figsize=(10, 5))
sns.histplot(feature, ax=ax, stat='probability', kde=True)
ax.axvline(mean, color = 'red', label=f'Mean = {mean:,.2f}')
ax.axvline(median, ls = '--', color = 'green', label=f'Median = {median:,.2f}')
ax.axvline(plus_one_std, color='black', label=f'+1 std = {plus_one_std:,.2f}')
ax.axvline(minus_one_std, color = 'black', label = f'-1 std = {minus_one_std:,.2f}')
ax.axvspan(plus_one_std, minus_one_std, color='yellow', zorder=0)
ax.set_title(f'{col}')
ax.legend();

# %% [markdown]
# ## VitD_levels Questions
#
# - **Is it Descrete or Continous?** | *It is Continous.*
# - **Does it have a skew? If so, which direction (+/-)** | *It has a normal skew, neither positive or negative leaning.*
#
# - **What type of kurtosis does it display? (Mesokurtic, Leptokurtic, or Platykurtic)** | *It displays Leptokurtic*

# %%
# Create a histogram of Doc_visits
col = 'Doc_visits'
feature = df_med[col]
mean = feature.mean()
median = feature.median()
std = feature.std()
plus_one_std = mean + std
minus_one_std = mean - std

# Use the same points as the first histogram
fig, ax = plt.subplots(figsize=(10,5))
sns.histplot(feature, ax=ax, stat='probability', kde=True)
ax.axvline(mean, color = 'red', label=f'Mean = {mean:,.2f}')
ax.axvline(median, ls = '--', color = 'green', label=f'Median = {median:,.2f}')
ax.axvline(plus_one_std, color='black', label=f'+1 std = {plus_one_std:,.2f}')
ax.axvline(minus_one_std, color = 'black', label = f'-1 std = {minus_one_std:,.2f}')
ax.axvspan(plus_one_std, minus_one_std, color='yellow', zorder=0)
ax.set_title(f'{col}')
ax.legend();

# %% [markdown]
# ## Doc_visits Questions
#
# - **Is it Descrete or Continous?** | *It is Discrete.*
# - **Does it have a skew? If so, which direction (+/-)** | *It has a normal skew, neither positive or negative leaning.*
#
# - **What type of kurtosis does it display? (Mesokurtic, Leptokurtic, or Platykurtic)** | *It displays Mesokurtic*

# %%
# Create a histogram of 'TotalChange'
col = 'TotalCharge'
feature = df_med[col]
mean = feature.mean()
median = feature.median()
std = feature.std()
plus_one_std = mean + std
minus_one_std = mean - std

# Use the same points as the first histogram
fig, ax = plt.subplots(figsize=(10,6))
sns.histplot(feature, ax=ax, stat='probability', kde=True)
ax.axvline(mean, color = 'red', label=f'Mean = {mean:,.2f}')
ax.axvline(median, ls = '--', color = 'green', label=f'Median = {median:,.2f}')
ax.axvline(plus_one_std, color='black', label=f'+1 std = {plus_one_std:,.2f}')
ax.axvline(minus_one_std, color = 'black', label = f'-1 std = {minus_one_std:,.2f}')
ax.axvspan(plus_one_std, minus_one_std, color='yellow', zorder=0)
ax.set_title(f'{col}')
ax.legend();

# %% [markdown]
# ## TotalCharge Questions
#
# - **Is it Descrete or Continous?** | *It is Continuous.*
# - **Does it have a skew? If so, which direction (+/-)** | *It has a skew that is leaning in a postive direction.*
#
# - **What type of kurtosis does it display? (Mesokurtic, Leptokurtic, or Platykurtic)** | *It displays Leptokurtic*
